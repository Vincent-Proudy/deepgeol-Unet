# %% [markdown]
# # Testing notebook for DeepGeol
#
# > vincent.proudy.etu@univ-lemans.fr - 2026-03-14
#
# We testing Unet model trained on the training set and evaluate its performance on the test set (unknown data) using various metrics such as accuracy, loss, F1 score, and UIO (Jaccard index).

# %% [markdown]
# Load the necessary libraries and modules, including the training loop and testing functions.

# %%
from DeepGeol.deepgeol.train_loop import *

# %% [markdown]
# Train the model for a specified number of epochs and return a graph of the training process. This train loop implements early stopping to prevent overfitting and ensure that the model generalizes well to unknow data.

# %%
model = train_loop(epochs=30)
# Out:
# Using GPU device
# Training Progress:  93%|█████████▎| 28/30 [04:19<00:18,  9.26s/epoch]
# Early stopping triggered at epoch 29

# %% [markdown]
# This test function evaluates the performance of the trained model on the test set (unknown data) and returns various metrics such as accuracy, loss, F1 score, and UIO. The UOI is a Jaccard index that measures the overlap between the predicted and true labels, providing insight into the model's ability to correctly classify the unknown data.

# %%
accuracy, loss, f1, uio = test(model)
# Out:
# Using GPU device
# Test metrics :
#   Accuracy: 95.06%
#   Loss: 0.210001
#   F1: 0.8668
#   Jaccard Index: 0.7649
